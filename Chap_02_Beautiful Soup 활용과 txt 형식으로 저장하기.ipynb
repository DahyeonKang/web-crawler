# %%
# riss.kr 에서 특정 키워드로 논문 / 학술 자료 검색하기

#Step 1. 필요한 모듈을 로딩합니다
from selenium import webdriver
import time          

#Step 2. 사용자에게 검색 관련 정보들을 입력 받습니다.
print("=" *100)
print(" 이 크롤러는 RISS 사이트의 논문 및 학술자료 수집용 웹크롤러입니다.")
print("=" *100)
query_txt = input('1.수집할 자료의 키워드는 무엇입니까?(여러개일 경우 , 로 구분하여 입력): ')
print("\n")

#Step 3. 크롬 드라이버 설정 및 웹 페이지 열기
#chrome_path = "c:/py_temp/chromedriver_88.exe"
driver = webdriver.Chrome()

url = 'http://www.riss.kr/'
driver.get(url)
time.sleep(2)

#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element_by_id("query")
driver.find_element_by_id("query").click( )
element.send_keys(query_txt)
element.send_keys("\n")
time.sleep(2)

#Step 5.학위 논문 선택하기
driver.find_element_by_link_text('학위논문').click()
time.sleep(2)

#Step 6.Beautiful Soup 로 본문 내용만 추출하기
from bs4 import BeautifulSoup
html_1 = driver.page_source  #원본: 현재 페이지의 전체 소스코드를 다 가져오기
soup_1 = BeautifulSoup(html_1, 'html.parser')  #분석본

# class 생략 가능 content_1 = soup_1.find('div', class_ = 'srchResultListW').find_all('li')
content_1 = soup_1.find('div','srchResultListW').find_all('li')

for i in content_1 :
    print(i.get_text().replace("\n"," ").strip())
    print("\n")

    
#Step 7. 표준 출력 방향을 바꾸어 txt 파일에 저장하기
import sys 
f_name = input('결과를 저장할 파일명을 쓰세요(예: c:\\temp\\riss.txt): ')

orig_stdout = sys.stdout
file = open(f_name , 'a' , encoding='UTF-8')
sys.stdout = file  #모니터에 출력하지 말고 file 에 출력해라

for i in content_1 :
    print(i.get_text().replace("\n",""))

file.close()    
sys.stdout = orig_stdout  #원래대로 변경 - 다시 화면에 출력시켜라    

print('요청하신 데이터 수집 작업이 정상적으로 완료되었습니다')
print('수집된 결과는 %s 에 저장되었습니다' %f_name)
# Out:
# ====================================================================================================
#  이 크롤러는 RISS 사이트의 논문 및 학술자료 수집용 웹크롤러입니다.
# ====================================================================================================
# 1.수집할 자료의 키워드는 무엇입니까?(여러개일 경우 , 로 구분하여 입력): 빅데이터
#
#
# 1   조직에서의 빅데이터 시스템 도입을 위한 결정요인에 대한 연구  이선우 성균관대학교 일반대학원 2016 국내박사  RANK : 13634431    원문보기 목차검색조회  음성듣기
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
# 2   빅데이터 기술에 기반한 그린IT 분류체계 수립 및 그린IT 활성화를 위한 전략적 과제 연구 : 비즈니스 활성화와 정책수립 관점  백현 한양사이버대학교 경영대학원 2014 국내석사  RANK : 13634431    원문보기 목차검색조회  음성듣기
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
# 3   기업의 빅데이터 활용 유형별 적용 방안 및 효과 분석  이재성 한신대학교 대학원 2014 국내박사  RANK : 13634431    원문보기 목차검색조회  음성듣기
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
# 4   SNS빅데이터를 활용한 디지털사이니지 영상콘텐츠 디자인 연구 : 디지털사이니지 매거진TV를 중심으로  이진우 홍익대학교 영상대학원 2014 국내석사  RANK : 13634431    원문보기 목차검색조회  음성듣기
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
# 5   빅데이터의 지식재산권 문제에 관한 연구  이이삭 성균관대학교 2015 국내석사  RANK : 13634431    원문보기 목차검색조회  음성듣기
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
# 6   빅 데이터 플랫폼을 이용한 풍력 발전기 SCADA 데이터 분석의 시각화 기술 연구  박상준 단국대학교 2015 국내석사  RANK : 13634431    원문보기 목차검색조회  음성듣기
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
# 7   e-CRM이 고객 만족에 미치는 영향에 관한 연구 : 빅데이터 활용을 중심으로  이원일 한성대학교 지식서비스&컨설팅대학원 2015 국내석사  RANK : 13634431    원문보기 목차검색조회  음성듣기
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
# 8   데이터 시각화를 이용한 미디어아트 : 빅 데이터 시각화 작품 <Earth>를 중심으로  손진석 숭실대학교 대학원 2015 국내석사  RANK : 13634431    원문보기 목차검색조회  음성듣기
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
# 9   빅데이터를 활용한 사용자 경험디자인 요소 추출 방법에 관한 연구  홍민석 한양대학교 2016 국내석사  RANK : 13634431    원문보기  음성듣기
#
#
# 원문보기
#
#
# 음성듣기
#
#
# 10   토픽모델링을 이용한 빅데이터 동향의 다각적 분석  민혜종 서울과학기술대학교 2015 국내석사  RANK : 13634431    원문보기 목차검색조회  음성듣기
#
#
# 원문보기
#
#
# 목차검색조회
#
#
# 음성듣기
#
#
# 결과를 저장할 파일명을 쓰세요(예: c:\temp\riss.txt): 크롤러riss_빅데이터_검색_논문
# 요청하신 데이터 수집 작업이 정상적으로 완료되었습니다
# 수집된 결과는 크롤러riss_빅데이터_검색_논문 에 저장되었습니다
